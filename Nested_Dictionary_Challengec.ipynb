# %% [markdown]
# # Nested Dictionary Challenge

# %%
employee = {
    "name": "Amit",
    "department": "Engineering",
    "skills": {
        "language": "Python",
        "database": "PostgreSQL",
        "cloud": "AWS"
    },
    "salary": 80000
}

# %%
# Print employee name
print(employee["name"])
# Out:
# Amit

# %%
# Print department
print(employee["department"])
# Out:
# Engineering

# %%
# Print complete skills dictionary
print(employee["skills"])
# Out:
# {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}

# %%
# Print programming language
print(employee["skills"]["language"])
# Out:
# Python

# %%
# Print database
print(employee["skills"]["database"])
# Out:
# PostgreSQL

# %%
# Print cloud technology
print(employee["skills"]["cloud"])
# Out:
# AWS

# %%
# Change Python to Python + JavaScript
employee["skills"]["language"] = "Python + JavaScript"

# %%
# Change salary
employee["salary"] = 90000

# %%
# Add experience
employee["experience"] = 3

# %%
# Add another skill
employee["skills"]["framework"] = "Django"

# %%
# Print updated employee dictionary
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS', 'framework': 'Django'}, 'salary': 90000, 'experience': 3}

# %%
#How nested dictionaries work

# A nested dictionary means a dictionary inside another dictionary.

# Here, skills is a dictionary inside employee:
skills= {
    "language": "Python",
    "database": "PostgreSQL",
    "cloud": "AWS"
}

# To access values:

employee["name"]

#➡️ Gets the name: Amit

employee["skills"]["language"]
# Out:
# 'Python + JavaScript'

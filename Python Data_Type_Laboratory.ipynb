# %% [markdown]
# # 15+ Variables with Different Data Types

# %%
# int (Integer)
age = 25.1
marks = 90
year = 2026

# %%
print(type(age))
# Out:
# <class 'float'>

# %%
# float (Decimal number)
price = 99.99
height = 5.8
percentage = 85.5

# %%
print(type(price))
# Out:
# <class 'float'>

# %%
# str (String/Text)
name = "Arif"
course = "Python"
city = "Delhi"
num="100"

# %%
print(type(num))
# Out:
# <class 'str'>

# %%
# bool (True/False)
is_student = True 
has_job = False

# %%
print(type(is_student))
# Out:
# <class 'bool'>

# %%
# list (Ordered and changeable collection)
numbers = [1, 2, 3, 4]
fruits = ["Apple", "Banana", "Mango"]

# %%
print(type(numbers))
# Out:
# <class 'list'>

# %%
# tuple (Ordered but cannot be changed)
coordinates = (10, 20)
colors = ("Red", "Green", "Blue")

# %%
type(coordinates)
# Out:
# tuple

# %%
# set (Unique values)
unique_numbers = {1, 2, 3, 4}
unique_numbers2 = {5,6,7,8}
languages = {"Python", "Java", "C++"}

# %%
print(type(unique_numbers2))
# Out:
# <class 'set'>

# %%
# dict (Key and value pairs)
student = {
    "name": "Arif",
    "age": 25
}

employee = {
    "name": "Rahul",
    "salary": 50000
}

# %%
print(type(employee))
# Out:
# <class 'dict'>

# %%
# Using type() to Check Data Type
# =========================

print(type(age))
print(type(price))
print(type(name))
print(type(is_student))
print(type(numbers))
print(type(coordinates))
print(type(unique_numbers))
print(type(student))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'dict'>

# %%
# int
a="100"
b="python"

c=int(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 5
#       1 # int
#       2 a="100"
#       3 b="python"
#       4
# ----> 5 c=int(b)
#
# ValueError: invalid literal for int() with base 10: 'python'

# %%
print(type(c))
# Out:
# <class 'int'>

# %%
a="34.5"
c=float(a)

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
tup=(1,2,3,4,5)
lis=list(tup)

# %%
t2=tuple(lis)

# %%
type(lis)
# Out:
# list
